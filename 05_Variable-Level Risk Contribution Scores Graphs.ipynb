# %%
import pandas as pd

# Defining data for variable level risk contribution score under every attack strategy
data = [
    # Canada – Religion
    ["Canada", "Religion", "Equal Weights", "age", 31640, 0.0559, 0.0550],
    ["Canada", "Religion", "Equal Weights", "sex", 31935, 0.0570, 0.0566],
    ["Canada", "Religion", "Equal Weights", "marstat", 31729, 0.0558, 0.0551],
    ["Canada", "Religion", "Equal Weights", "minority", 31707, 0.0576, 0.0568],
    ["Canada", "Religion", "Equal Weights", "empstat", 31530, 0.0556, 0.0545],
    ["Canada", "Religion", "Equal Weights", "birthplace", 28468, 0.0584, 0.0517],

    ["Canada", "Religion", "Data Availability", "age", 31640, 0.0601, 0.0591],
    ["Canada", "Religion", "Data Availability", "sex", 31935, 0.0611, 0.0607],
    ["Canada", "Religion", "Data Availability", "marstat", 30147, 0.0558, 0.0523],
    ["Canada", "Religion", "Data Availability", "minority", 31736, 0.0618, 0.0610],
    ["Canada", "Religion", "Data Availability", "empstat", 31739, 0.0603, 0.0595],
    ["Canada", "Religion", "Data Availability", "birthplace", 29812, 0.0620, 0.0575],

    ["Canada", "Religion", "Intruder Perspective", "age", 30413, 0.0688, 0.0650],
    ["Canada", "Religion", "Intruder Perspective", "sex", 30529, 0.0624, 0.0593],
    ["Canada", "Religion", "Intruder Perspective", "marstat", 30848, 0.0666, 0.0639],
    ["Canada", "Religion", "Intruder Perspective", "minority", 31925, 0.0707, 0.0702],
    ["Canada", "Religion", "Intruder Perspective", "empstat", 31462, 0.0674, 0.0659],
    ["Canada", "Religion", "Intruder Perspective", "birthplace", 31832, 0.0706, 0.0699],

    # Canada – Citizen
    ["Canada", "Citizen", "Equal Weights", "age", 31640, 0.8425, 0.8292],
    ["Canada", "Citizen", "Equal Weights", "sex", 31935, 0.8385, 0.8329],
    ["Canada", "Citizen", "Equal Weights", "marstat", 31729, 0.8398, 0.8288],
    ["Canada", "Citizen", "Equal Weights", "minority", 31707, 0.8380, 0.8265],
    ["Canada", "Citizen", "Equal Weights", "empstat", 31530, 0.8399, 0.8237],
    ["Canada", "Citizen", "Equal Weights", "birthplace", 28468, 0.9175, 0.8124],

    ["Canada", "Citizen", "Data Availability", "age", 31640, 0.8658, 0.8521],
    ["Canada", "Citizen", "Data Availability", "sex", 31935, 0.8615, 0.8558],
    ["Canada", "Citizen", "Data Availability", "marstat", 30147, 0.8640, 0.8102],
    ["Canada", "Citizen", "Data Availability", "minority", 31736, 0.8613, 0.8502],
    ["Canada", "Citizen", "Data Availability", "empstat", 31739, 0.8634, 0.8523],
    ["Canada", "Citizen", "Data Availability", "birthplace", 29812, 0.9138, 0.8473],

    ["Canada", "Citizen", "Intruder Perspective", "age", 30413, 0.9145, 0.8651],
    ["Canada", "Citizen", "Intruder Perspective", "sex", 30529, 0.8965, 0.8513],
    ["Canada", "Citizen", "Intruder Perspective", "marstat", 31100, 0.8980, 0.8687],
    ["Canada", "Citizen", "Intruder Perspective", "minority", 31890, 0.8941, 0.8869],
    ["Canada", "Citizen", "Intruder Perspective", "empstat", 31210, 0.8973, 0.8711],
    ["Canada", "Citizen", "Intruder Perspective", "birthplace", 31867, 0.8965, 0.8886],

    # Canada – Tenure
    ["Canada", "Tenure", "Equal Weights", "age", 31640, 0.1538, 0.1514],
    ["Canada", "Tenure", "Equal Weights", "sex", 31935, 0.1547, 0.1537],
    ["Canada", "Tenure", "Equal Weights", "marstat", 31729, 0.1538, 0.1518],
    ["Canada", "Tenure", "Equal Weights", "minority", 31707, 0.1550, 0.1529],
    ["Canada", "Tenure", "Equal Weights", "empstat", 31530, 0.1532, 0.1503],
    ["Canada", "Tenure", "Equal Weights", "birthplace", 28468, 0.1557, 0.1379],

    ["Canada", "Tenure", "Data Availability", "age", 31640, 0.1660, 0.1633],
    ["Canada", "Tenure", "Data Availability", "sex", 31935, 0.1667, 0.1656],
    ["Canada", "Tenure", "Data Availability", "marstat", 30147, 0.1548, 0.1451],
    ["Canada", "Tenure", "Data Availability", "minority", 31736, 0.1672, 0.1650],
    ["Canada", "Tenure", "Data Availability", "empstat", 31739, 0.1656, 0.1635],
    ["Canada", "Tenure", "Data Availability", "birthplace", 29812, 0.1671, 0.1550],

    ["Canada", "Tenure", "Intruder Perspective", "age", 31252, 0.1700, 0.1653],
    ["Canada", "Tenure", "Intruder Perspective", "sex", 30529, 0.1511, 0.1435],
    ["Canada", "Tenure", "Intruder Perspective", "marstat", 31963, 0.1709, 0.1699],
    ["Canada", "Tenure", "Intruder Perspective", "minority", 31414, 0.1689, 0.1651],
    ["Canada", "Tenure", "Intruder Perspective", "empstat", 31969, 0.1709, 0.1699],
    ["Canada", "Tenure", "Intruder Perspective", "birthplace", 29882, 0.1735, 0.1613],
]

# Creating DataFrame
columns = ["Country", "Target", "Method", "Variable", "Count", "Avg CAP", "Risk Contribution"]
df = pd.DataFrame(data, columns=columns)

# Displaying the DataFrame
df  # showing first 10 rows
# Out:
#    Country    Target                Method    Variable  Count  Avg CAP  \
# 0   Canada  Religion         Equal Weights         age  31640   0.0559
# 1   Canada  Religion         Equal Weights         sex  31935   0.0570
# 2   Canada  Religion         Equal Weights     marstat  31729   0.0558
# 3   Canada  Religion         Equal Weights    minority  31707   0.0576
# 4   Canada  Religion         Equal Weights     empstat  31530   0.0556
# 5   Canada  Religion         Equal Weights  birthplace  28468   0.0584
# 6   Canada  Religion     Data Availability         age  31640   0.0601
# 7   Canada  Religion     Data Availability         sex  31935   0.0611
# 8   Canada  Religion     Data Availability     marstat  30147   0.0558
# 9   Canada  Religion     Data Availability    minority  31736   0.0618
# 10  Canada  Religion     Data Availability     empstat  31739   0.0603
# 11  Canada  Religion     Data Availability  birthplace  29812   0.0620
# ...

# %%
# Sorting descending to highlight top contributors per method
avg_risk = avg_risk.sort_values(by=["Method", "Risk Contribution"], ascending=[True, False])

avg_risk
# Out:
#       Variable                Method  Risk Contribution
# 15         sex     Data Availability           0.360700
# 12    minority     Data Availability           0.358733
# 6      empstat     Data Availability           0.358433
# 0          age     Data Availability           0.358167
# 3   birthplace     Data Availability           0.353267
# 9      marstat     Data Availability           0.335867
# 16         sex         Equal Weights           0.347733
# 13    minority         Equal Weights           0.345400
# 10     marstat         Equal Weights           0.345233
# 1          age         Equal Weights           0.345200
# 7      empstat         Equal Weights           0.342833
# 4   birthplace         Equal Weights           0.334000
# 14    minority  Intruder Perspective           0.374067
# 5   birthplace  Intruder Perspective           0.373267
# 8      empstat  Intruder Perspective           0.368967
# 11     marstat  Intruder Perspective           0.367500
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filtering for Canada
canada_df = df[df["Country"] == "Canada"]

# Calculating average Risk Contribution per Variable and Method (across all targets)
avg_risk = canada_df.groupby(["Method", "Variable"], as_index=False)["Risk Contribution"].mean()

#  Plot - Clustered Bar Chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=avg_risk,
    x="Method",
    y="Risk Contribution",
    hue="Variable",
    dodge=True
)

# Titles and labels
plt.title("Variable-Level Risk Contribution by Method (Canada)")
plt.ylabel("Average Risk Contribution")
plt.xlabel("Weighting Method")
legend = ax.legend(
    title="Variable",
    loc='lower right',
    bbox_to_anchor=(1, 0),
    bbox_transform=ax.transAxes,
    frameon=True
)

plt.tight_layout()
canadariskcontr = "/Users/idilalp/Desktop/canadariskcontr.png"
plt.savefig(canadariskcontr, dpi=300, bbox_inches='tight')
plt.show()

# %%
#  repeating the same process for all datasets
import pandas as pd

# import the Fiji data 
fiji_data = [
    # === Religion – Equal Weights ===
    ["Fiji", "Religion", "Equal Weights", "age", 83747, 0.0614, 0.0610],
    ["Fiji", "Religion", "Equal Weights", "sex", 84069, 0.0614, 0.0613],
    ["Fiji", "Religion", "Equal Weights", "marstat", 83645, 0.0609, 0.0605],
    ["Fiji", "Religion", "Equal Weights", "ethnic", 83215, 0.0616, 0.0608],
    ["Fiji", "Religion", "Equal Weights", "empstat", 83705, 0.0607, 0.0603],
    ["Fiji", "Religion", "Equal Weights", "birthpl", 77107, 0.0586, 0.0536],

    # === Religion – Data Availability ===
    ["Fiji", "Religion", "Data Availability", "age", 83747, 0.0631, 0.0627],
    ["Fiji", "Religion", "Data Availability", "sex", 84069, 0.0631, 0.0629],
    ["Fiji", "Religion", "Data Availability", "marstat", 79804, 0.0583, 0.0551],
    ["Fiji", "Religion", "Data Availability", "ethnic", 83337, 0.0633, 0.0626],
    ["Fiji", "Religion", "Data Availability", "empstat", 83885, 0.0628, 0.0625],
    ["Fiji", "Religion", "Data Availability", "birthpl", 80646, 0.0627, 0.0599],

    # === Religion – Intruder Perspective ===
    ["Fiji", "Religion", "Intruder Perspective", "age", 78355, 0.0636, 0.0591],
    ["Fiji", "Religion", "Intruder Perspective", "sex", 81266, 0.0567, 0.0546],
    ["Fiji", "Religion", "Intruder Perspective", "marstat", 83988, 0.0626, 0.0623],
    ["Fiji", "Religion", "Intruder Perspective", "ethnic", 83906, 0.0627, 0.0624],
    ["Fiji", "Religion", "Intruder Perspective", "empstat", 84065, 0.0627, 0.0625],
    ["Fiji", "Religion", "Intruder Perspective", "birthpl", 83908, 0.0627, 0.0623],

    # === Worktype – Equal Weights ===
    ["Fiji", "Worktype", "Equal Weights", "age", 83747, 0.2076, 0.2062],
    ["Fiji", "Worktype", "Equal Weights", "sex", 84069, 0.2077, 0.2070],
    ["Fiji", "Worktype", "Equal Weights", "marstat", 83645, 0.2074, 0.2057],
    ["Fiji", "Worktype", "Equal Weights", "ethnic", 83215, 0.2074, 0.2046],
    ["Fiji", "Worktype", "Equal Weights", "empstat", 83705, 0.2078, 0.2063],
    ["Fiji", "Worktype", "Equal Weights", "birthpl", 77107, 0.2034, 0.1860],

    # === Worktype – Data Availability ===
    ["Fiji", "Worktype", "Data Availability", "age", 83747, 0.2086, 0.2072],
    ["Fiji", "Worktype", "Data Availability", "sex", 84069, 0.2087, 0.2081],
    ["Fiji", "Worktype", "Data Availability", "marstat", 79804, 0.2068, 0.1957],
    ["Fiji", "Worktype", "Data Availability", "ethnic", 83337, 0.2087, 0.2062],
    ["Fiji", "Worktype", "Data Availability", "empstat", 83885, 0.2088, 0.2077],
    ["Fiji", "Worktype", "Data Availability", "birthpl", 80646, 0.2051, 0.1961],

    # === Worktype – Intruder Perspective ===
    ["Fiji", "Worktype", "Intruder Perspective", "age", 83747, 0.2079, 0.2064],
    ["Fiji", "Worktype", "Intruder Perspective", "sex", 83971, 0.2076, 0.2067],
    ["Fiji", "Worktype", "Intruder Perspective", "marstat", 83592, 0.2077, 0.2059],
    ["Fiji", "Worktype", "Intruder Perspective", "ethnic", 83070, 0.2078, 0.2047],
    ["Fiji", "Worktype", "Intruder Perspective", "empstat", 84001, 0.2080, 0.2073],
    ["Fiji", "Worktype", "Intruder Perspective", "birthpl", 77107, 0.2038, 0.1863],

    # === Tenure – Equal Weights ===
    ["Fiji", "Tenure", "Equal Weights", "age", 83747, 0.1752, 0.1740],
    ["Fiji", "Tenure", "Equal Weights", "sex", 84069, 0.1752, 0.1747],
    ["Fiji", "Tenure", "Equal Weights", "marstat", 83645, 0.1744, 0.1730],
    ["Fiji", "Tenure", "Equal Weights", "ethnic", 83215, 0.1745, 0.1722],
    ["Fiji", "Tenure", "Equal Weights", "empstat", 83705, 0.1739, 0.1727],
    ["Fiji", "Tenure", "Equal Weights", "birthpl", 77107, 0.1681, 0.1537],

    # === Tenure – Data Availability ===
    ["Fiji", "Tenure", "Data Availability", "age", 83747, 0.1783, 0.1770],
    ["Fiji", "Tenure", "Data Availability", "sex", 84069, 0.1783, 0.1777],
    ["Fiji", "Tenure", "Data Availability", "marstat", 79804, 0.1687, 0.1596],
    ["Fiji", "Tenure", "Data Availability", "ethnic", 83337, 0.1778, 0.1758],
    ["Fiji", "Tenure", "Data Availability", "empstat", 83885, 0.1778, 0.1769],
    ["Fiji", "Tenure", "Data Availability", "birthpl", 80646, 0.1761, 0.1684],

    # === Tenure – Intruder Perspective ===
    ["Fiji", "Tenure", "Intruder Perspective", "age", 80968, 0.1841, 0.1768],
    ["Fiji", "Tenure", "Intruder Perspective", "sex", 81266, 0.1720, 0.1658],
    ["Fiji", "Tenure", "Intruder Perspective", "marstat", 81375, 0.1786, 0.1723],
    ["Fiji", "Tenure", "Intruder Perspective", "ethnic", 83790, 0.1842, 0.1830],
    ["Fiji", "Tenure", "Intruder Perspective", "empstat", 84082, 0.1845, 0.1839],
    ["Fiji", "Tenure", "Intruder Perspective", "birthpl", 84007, 0.1843, 0.1836],
]

# Create DataFrame
fiji_df = pd.DataFrame(fiji_data, columns=["Country", "Target", "Method", "Variable", "Count", "Avg CAP", "Risk Contribution"])


fiji_df
# Out:
#    Country    Target                Method Variable  Count  Avg CAP  \
# 0     Fiji  Religion         Equal Weights      age  83747   0.0614
# 1     Fiji  Religion         Equal Weights      sex  84069   0.0614
# 2     Fiji  Religion         Equal Weights  marstat  83645   0.0609
# 3     Fiji  Religion         Equal Weights   ethnic  83215   0.0616
# 4     Fiji  Religion         Equal Weights  empstat  83705   0.0607
# 5     Fiji  Religion         Equal Weights  birthpl  77107   0.0586
# 6     Fiji  Religion     Data Availability      age  83747   0.0631
# 7     Fiji  Religion     Data Availability      sex  84069   0.0631
# 8     Fiji  Religion     Data Availability  marstat  79804   0.0583
# 9     Fiji  Religion     Data Availability   ethnic  83337   0.0633
# 10    Fiji  Religion     Data Availability  empstat  83885   0.0628
# 11    Fiji  Religion     Data Availability  birthpl  80646   0.0627
# 12    Fiji  Religion  Intruder Perspective      age  78355   0.0636
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Calculating average Risk Contribution per Variable and Method (across all targets)
avg_risk_fiji = fiji_df.groupby(["Method", "Variable"], as_index=False)["Risk Contribution"].mean()

#  Plot - Clustered Bar Chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=avg_risk_fiji,
    x="Method",
    y="Risk Contribution",
    hue="Variable",
    dodge=True
)

plt.title("Variable-Level Risk Contribution by Method (Fiji)")
plt.ylabel("Average Risk Contribution")
plt.xlabel("Weighting Method")
plt.tight_layout()
ax.legend(title="Variable", loc='lower right')

fijiriskcontr = "/Users/idilalp/Desktop/fijiriskcontr.png"
plt.savefig(fijiriskcontr, dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd

# Rwanda – Religion
rwanda_religion_data = [
    ["Rwanda", "Religion", "Equal Weights", "age", 31326, 0.0173, 0.0172],
    ["Rwanda", "Religion", "Equal Weights", "sex", 31403, 0.0180, 0.0179],
    ["Rwanda", "Religion", "Equal Weights", "marstat", 31290, 0.0180, 0.0179],
    ["Rwanda", "Religion", "Equal Weights", "urban", 31370, 0.0181, 0.0181],
    ["Rwanda", "Religion", "Equal Weights", "empstat", 31061, 0.0177, 0.0175],
    ["Rwanda", "Religion", "Equal Weights", "birthplace", 30210, 0.0172, 0.0165],

    ["Rwanda", "Religion", "Data Availability", "age", 31326, 0.0173, 0.0172],
    ["Rwanda", "Religion", "Data Availability", "sex", 31403, 0.0180, 0.0179],
    ["Rwanda", "Religion", "Data Availability", "marstat", 31290, 0.0180, 0.0179],
    ["Rwanda", "Religion", "Data Availability", "urban", 31370, 0.0181, 0.0181],
    ["Rwanda", "Religion", "Data Availability", "empstat", 31061, 0.0177, 0.0175],
    ["Rwanda", "Religion", "Data Availability", "birthplace", 30210, 0.0172, 0.0165],

    ["Rwanda", "Religion", "Intruder Perspective", "age", 29757, 0.0155, 0.0147],
    ["Rwanda", "Religion", "Intruder Perspective", "sex", 31408, 0.0190, 0.0189],
    ["Rwanda", "Religion", "Intruder Perspective", "marstat", 31407, 0.0190, 0.0190],
    ["Rwanda", "Religion", "Intruder Perspective", "urban", 31412, 0.0191, 0.0191],
    ["Rwanda", "Religion", "Intruder Perspective", "empstat", 31394, 0.0190, 0.0190],
    ["Rwanda", "Religion", "Intruder Perspective", "birthplace", 31282, 0.0189, 0.0188],
]

# Rwanda – EmpSector
rwanda_empsector_data = [
    ["Rwanda", "EmpSector", "Equal Weights", "age", 31326, 0.1089, 0.1084],
    ["Rwanda", "EmpSector", "Equal Weights", "sex", 31403, 0.1094, 0.1092],
    ["Rwanda", "EmpSector", "Equal Weights", "marstat", 31290, 0.1086, 0.1080],
    ["Rwanda", "EmpSector", "Equal Weights", "urban", 31370, 0.1092, 0.1089],
    ["Rwanda", "EmpSector", "Equal Weights", "empstat", 31061, 0.1082, 0.1069],
    ["Rwanda", "EmpSector", "Equal Weights", "birthplace", 30210, 0.1045, 0.1004],

    ["Rwanda", "EmpSector", "Data Availability", "age", 31326, 0.1106, 0.1101],
    ["Rwanda", "EmpSector", "Data Availability", "sex", 31403, 0.1111, 0.1109],
    ["Rwanda", "EmpSector", "Data Availability", "marstat", 31050, 0.1081, 0.1067],
    ["Rwanda", "EmpSector", "Data Availability", "urban", 31115, 0.1083, 0.1071],
    ["Rwanda", "EmpSector", "Data Availability", "empstat", 31295, 0.1112, 0.1107],
    ["Rwanda", "EmpSector", "Data Availability", "birthplace", 30471, 0.1082, 0.1048],

    ["Rwanda", "EmpSector", "Intruder Perspective", "age", 31083, 0.1134, 0.1121],
    ["Rwanda", "EmpSector", "Intruder Perspective", "sex", 30964, 0.1079, 0.1062],
    ["Rwanda", "EmpSector", "Intruder Perspective", "marstat", 31407, 0.1145, 0.1143],
    ["Rwanda", "EmpSector", "Intruder Perspective", "urban", 31244, 0.1127, 0.1119],
    ["Rwanda", "EmpSector", "Intruder Perspective", "empstat", 31409, 0.1147, 0.1145],
    ["Rwanda", "EmpSector", "Intruder Perspective", "birthplace", 30553, 0.1112, 0.1080],
]

# Rwanda – Tenure
rwanda_tenure_data = [
    ["Rwanda", "Tenure", "Equal Weights", "age", 31326, 0.1279, 0.1274],
    ["Rwanda", "Tenure", "Equal Weights", "sex", 31403, 0.1278, 0.1275],
    ["Rwanda", "Tenure", "Equal Weights", "marstat", 31290, 0.1273, 0.1266],
    ["Rwanda", "Tenure", "Equal Weights", "urban", 31370, 0.1278, 0.1274],
    ["Rwanda", "Tenure", "Equal Weights", "empstat", 31061, 0.1252, 0.1236],
    ["Rwanda", "Tenure", "Equal Weights", "birthplace", 30210, 0.1258, 0.1208],

    ["Rwanda", "Tenure", "Data Availability", "age", 31326, 0.1282, 0.1276],
    ["Rwanda", "Tenure", "Data Availability", "sex", 31403, 0.1280, 0.1278],
    ["Rwanda", "Tenure", "Data Availability", "marstat", 31290, 0.1275, 0.1268],
    ["Rwanda", "Tenure", "Data Availability", "urban", 31277, 0.1269, 0.1262],
    ["Rwanda", "Tenure", "Data Availability", "empstat", 31154, 0.1263, 0.1251],
    ["Rwanda", "Tenure", "Data Availability", "birthplace", 30210, 0.1261, 0.1211],

    ["Rwanda", "Tenure", "Intruder Perspective", "age", 30470, 0.1312, 0.1271],
    ["Rwanda", "Tenure", "Intruder Perspective", "sex", 30964, 0.1299, 0.1278],
    ["Rwanda", "Tenure", "Intruder Perspective", "marstat", 31132, 0.1339, 0.1325],
    ["Rwanda", "Tenure", "Intruder Perspective", "urban", 31416, 0.1362, 0.1361],
    ["Rwanda", "Tenure", "Intruder Perspective", "empstat", 31396, 0.1359, 0.1357],
    ["Rwanda", "Tenure", "Intruder Perspective", "birthplace", 31282, 0.1362, 0.1355],
]

# Combine all Rwanda data
rwanda_data = rwanda_religion_data + rwanda_empsector_data + rwanda_tenure_data
rwanda_df = pd.DataFrame(rwanda_data, columns=["Country", "Target", "Method", "Variable", "Count", "Avg CAP", "Risk Contribution"])

rwanda_df
# Out:
#    Country     Target                Method    Variable  Count  Avg CAP  \
# 0   Rwanda   Religion         Equal Weights         age  31326   0.0173
# 1   Rwanda   Religion         Equal Weights         sex  31403   0.0180
# 2   Rwanda   Religion         Equal Weights     marstat  31290   0.0180
# 3   Rwanda   Religion         Equal Weights       urban  31370   0.0181
# 4   Rwanda   Religion         Equal Weights     empstat  31061   0.0177
# 5   Rwanda   Religion         Equal Weights  birthplace  30210   0.0172
# 6   Rwanda   Religion     Data Availability         age  31326   0.0173
# 7   Rwanda   Religion     Data Availability         sex  31403   0.0180
# 8   Rwanda   Religion     Data Availability     marstat  31290   0.0180
# 9   Rwanda   Religion     Data Availability       urban  31370   0.0181
# 10  Rwanda   Religion     Data Availability     empstat  31061   0.0177
# 11  Rwanda   Religion     Data Availability  birthplace  30210   0.0172
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculating average Risk Contribution per Variable and Method (across all targets)
avg_risk_rwanda = rwanda_df.groupby(["Method", "Variable"], as_index=False)["Risk Contribution"].mean()

#  Plot - Clustered Bar Chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=avg_risk_rwanda,
    x="Method",
    y="Risk Contribution",
    hue="Variable",
    dodge=True
)

plt.title("Variable-Level Risk Contribution by Method (Rwanda)")
plt.ylabel("Average Risk Contribution")
plt.xlabel("Weighting Method")
plt.tight_layout()

ax.legend(title="Variable", loc='lower right')

rwandariskcontr = "/Users/idilalp/Desktop/rwandariskcontr.png"
plt.savefig(rwandariskcontr, dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd

# UK Risk Contribution Data (including LTILL, TENURE, and FAMTYPE for all three methods)
uk_data = [
    # LTILL
    ["UK", "Ltill", "Equal Weights", "AGE", 103899, 0.5768, 0.5748],
    ["UK", "Ltill", "Equal Weights", "SEX", 104074, 0.5769, 0.5758],
    ["UK", "Ltill", "Equal Weights", "MSTATUS", 103972, 0.5768, 0.5751],
    ["UK", "Ltill", "Equal Weights", "ETHGROUP", 103280, 0.5767, 0.5712],
    ["UK", "Ltill", "Equal Weights", "ECONPRIM", 102985, 0.5778, 0.5707],
    ["UK", "Ltill", "Equal Weights", "AREAP", 90681, 0.5929, 0.5157],

    ["UK", "Ltill", "Data Availability", "AGE", 103899, 0.5770, 0.5750],
    ["UK", "Ltill", "Data Availability", "SEX", 104074, 0.5771, 0.5760],
    ["UK", "Ltill", "Data Availability", "MSTATUS", 103853, 0.5767, 0.5744],
    ["UK", "Ltill", "Data Availability", "ETHGROUP", 103399, 0.5769, 0.5721],
    ["UK", "Ltill", "Data Availability", "ECONPRIM", 102985, 0.5779, 0.5708],
    ["UK", "Ltill", "Data Availability", "AREAP", 90681, 0.5931, 0.5158],

    ["UK", "Ltill", "Intruder Perspective", "AGE", 103579, 0.5931, 0.5891],
    ["UK", "Ltill", "Intruder Perspective", "SEX", 99495, 0.5849, 0.5581],
    ["UK", "Ltill", "Intruder Perspective", "MSTATUS", 103791, 0.5924, 0.5897],
    ["UK", "Ltill", "Intruder Perspective", "ETHGROUP", 101200, 0.5912, 0.5738],
    ["UK", "Ltill", "Intruder Perspective", "ECONPRIM", 104013, 0.5929, 0.5914],
    ["UK", "Ltill", "Intruder Perspective", "AREAP", 96813, 0.6038, 0.5606],

    # TENURE
    ["UK", "Tenure", "Equal Weights", "AGE", 103899, 0.0992, 0.0988],
    ["UK", "Tenure", "Equal Weights", "SEX", 104074, 0.0993, 0.0991],
    ["UK", "Tenure", "Equal Weights", "MSTATUS", 103972, 0.0992, 0.0990],
    ["UK", "Tenure", "Equal Weights", "ETHGROUP", 103280, 0.0992, 0.0982],
    ["UK", "Tenure", "Equal Weights", "ECONPRIM", 102985, 0.0987, 0.0974],
    ["UK", "Tenure", "Equal Weights", "AREAP", 90681, 0.1044, 0.0908],

    ["UK", "Tenure", "Data Availability", "AGE", 103899, 0.0993, 0.0990],
    ["UK", "Tenure", "Data Availability", "SEX", 104074, 0.0995, 0.0993],
    ["UK", "Tenure", "Data Availability", "MSTATUS", 103853, 0.0992, 0.0988],
    ["UK", "Tenure", "Data Availability", "ETHGROUP", 103399, 0.0994, 0.0986],
    ["UK", "Tenure", "Data Availability", "ECONPRIM", 102985, 0.0988, 0.0976],
    ["UK", "Tenure", "Data Availability", "AREAP", 90681, 0.1046, 0.0909],

    ["UK", "Tenure", "Intruder Perspective", "AGE", 103899, 0.1094, 0.1090],
    ["UK", "Tenure", "Intruder Perspective", "SEX", 99495, 0.1018, 0.0971],
    ["UK", "Tenure", "Intruder Perspective", "MSTATUS", 103791, 0.1091, 0.1086],
    ["UK", "Tenure", "Intruder Perspective", "ETHGROUP", 102965, 0.1094, 0.1080],
    ["UK", "Tenure", "Intruder Perspective", "ECONPRIM", 103693, 0.1095, 0.1089],
    ["UK", "Tenure", "Intruder Perspective", "AREAP", 95048, 0.1127, 0.1028],

    # FAMTYPE
    ["UK", "Famtype", "Equal Weights", "AGE", 103899, 0.1515, 0.1510],
    ["UK", "Famtype", "Equal Weights", "SEX", 104074, 0.1517, 0.1514],
    ["UK", "Famtype", "Equal Weights", "MSTATUS", 103972, 0.1518, 0.1513],
    ["UK", "Famtype", "Equal Weights", "ETHGROUP", 103280, 0.1516, 0.1502],
    ["UK", "Famtype", "Equal Weights", "ECONPRIM", 102985, 0.1508, 0.1490],
    ["UK", "Famtype", "Equal Weights", "AREAP", 90681, 0.1570, 0.1366],

    ["UK", "Famtype", "Data Availability", "AGE", 103899, 0.1515, 0.1509],
    ["UK", "Famtype", "Data Availability", "SEX", 104074, 0.1517, 0.1514],
    ["UK", "Famtype", "Data Availability", "MSTATUS", 103853, 0.1517, 0.1511],
    ["UK", "Famtype", "Data Availability", "ETHGROUP", 103399, 0.1516, 0.1504],
    ["UK", "Famtype", "Data Availability", "ECONPRIM", 102985, 0.1508, 0.1489],
    ["UK", "Famtype", "Data Availability", "AREAP", 90681, 0.1570, 0.1365],

    ["UK", "Famtype", "Intruder Perspective", "AGE", 103822, 0.1515, 0.1509],
    ["UK", "Famtype", "Intruder Perspective", "SEX", 103991, 0.1515, 0.1511],
    ["UK", "Famtype", "Intruder Perspective", "MSTATUS", 104055, 0.1517, 0.1514],
    ["UK", "Famtype", "Intruder Perspective", "ETHGROUP", 102836, 0.1516, 0.1495],
    ["UK", "Famtype", "Intruder Perspective", "ECONPRIM", 103506, 0.1510, 0.1499],
    ["UK", "Famtype", "Intruder Perspective", "AREAP", 90681, 0.1570, 0.1366],
]

uk_columns = ["Country", "Target", "Method", "Variable", "Count", "Avg CAP", "Risk Contribution"]
uk_df = pd.DataFrame(uk_data, columns=uk_columns)


uk_df
# Out:
#    Country   Target                Method  Variable   Count  Avg CAP  \
# 0       UK    Ltill         Equal Weights       AGE  103899   0.5768
# 1       UK    Ltill         Equal Weights       SEX  104074   0.5769
# 2       UK    Ltill         Equal Weights   MSTATUS  103972   0.5768
# 3       UK    Ltill         Equal Weights  ETHGROUP  103280   0.5767
# 4       UK    Ltill         Equal Weights  ECONPRIM  102985   0.5778
# 5       UK    Ltill         Equal Weights     AREAP   90681   0.5929
# 6       UK    Ltill     Data Availability       AGE  103899   0.5770
# 7       UK    Ltill     Data Availability       SEX  104074   0.5771
# 8       UK    Ltill     Data Availability   MSTATUS  103853   0.5767
# 9       UK    Ltill     Data Availability  ETHGROUP  103399   0.5769
# 10      UK    Ltill     Data Availability  ECONPRIM  102985   0.5779
# 11      UK    Ltill     Data Availability     AREAP   90681   0.5931
# 12      UK    Ltill  Intruder Perspective       AGE  103579   0.5931
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#  Calculating average Risk Contribution per Variable and Method (across all targets)
avg_risk_uk = uk_df.groupby(["Method", "Variable"], as_index=False)["Risk Contribution"].mean()

#  Plot - Clustered Bar Chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=avg_risk_uk,
    x="Method",
    y="Risk Contribution",
    hue="Variable",
    dodge=True
)

plt.title("Variable-Level Risk Contribution by Method (UK)")
plt.ylabel("Average Risk Contribution")
plt.xlabel("Weighting Method")
plt.tight_layout()

ax.legend(title="Variable", loc='lower right')

ukriskcontr = "/Users/idilalp/Desktop/ukriskcontr.png"
plt.savefig(ukriskcontr, dpi=300, bbox_inches='tight')
plt.show()
